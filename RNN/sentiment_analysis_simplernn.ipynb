# %%
docs = ['prince kumar',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'virat kohli',
		'indira gandhi natonal open university',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 23

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[7, 8],
#  [1, 1],
#  [3, 3, 9],
#  [2, 10, 2, 1, 2],
#  [11, 12, 4, 5],
#  [13, 14],
#  [15, 16, 17, 18, 19],
#  [6, 6],
#  [20, 21, 4, 5],
#  [22, 23]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 7,  8,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3,  9,  0,  0],
#        [ 2, 10,  2,  1,  2],
#        [11, 12,  4,  5,  0],
#        [13, 14,  0,  0,  0],
#        [15, 16, 17, 18, 19],
#        [ 6,  6,  0,  0,  0],
#        [20, 21,  4,  5,  0],
#        [22, 23,  0,  0,  0]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(17,output_dim=2,input_length=5))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 845ms/step
# [[[-0.0120474   0.04543552]
#   [-0.01185112 -0.04153217]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]
#
#  [[-0.02943127  0.01758334]
#   [-0.02943127  0.01758334]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]
#
#  [[-0.02844912  0.03209073]
#   [-0.02844912  0.03209073]
#   [-0.02633934 -0.04383048]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]
#
#  [[-0.03866263 -0.0240912 ]
#   [-0.04060235  0.04071715]
#   [-0.03866263 -0.0240912 ]
#   [-0.02943127  0.01758334]
#   [-0.03866263 -0.0240912 ]]
#
#  [[-0.02793291  0.00202174]
#   [ 0.01500297 -0.04735615]
#   [-0.04084642 -0.04006237]
#   [-0.0172333   0.04490814]
#   [-0.03025825  0.01223611]]
#
#  [[-0.04458719  0.010192  ]
#   [-0.01462667  0.00356808]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]
#
#  [[ 0.02221587  0.03167233]
#   [-0.04641919  0.01843617]
#   [-0.04641919  0.01843617]
#   [-0.04641919  0.01843617]
#   [-0.04641919  0.01843617]]
#
#  [[ 0.03242126 -0.01493711]
#   [ 0.03242126 -0.01493711]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]
#
#  [[-0.04641919  0.01843617]
#   [-0.04641919  0.01843617]
#   [-0.04084642 -0.04006237]
#   [-0.0172333   0.04490814]
#   [-0.03025825  0.01223611]]
#
#  [[-0.04641919  0.01843617]
#   [-0.04641919  0.01843617]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]
#   [-0.03025825  0.01223611]]]

# %%
import tensorflow
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=200)
X_test = pad_sequences(X_test,padding='post',maxlen=200)

# %%
X_train.shape
# Out:
# (25000, 200)

# %%
model = Sequential()
model.add(Embedding(10000,50))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - acc: 0.5340 - loss: 0.6859 - val_acc: 0.5668 - val_loss: 0.6745
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - acc: 0.5917 - loss: 0.6463 - val_acc: 0.5620 - val_loss: 0.6668
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - acc: 0.6259 - loss: 0.5979 - val_acc: 0.5589 - val_loss: 0.6733
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - acc: 0.6377 - loss: 0.5705 - val_acc: 0.5794 - val_loss: 0.6752
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - acc: 0.6653 - loss: 0.5233 - val_acc: 0.5668 - val_loss: 0.7293
