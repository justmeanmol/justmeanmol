# %% [markdown]
# Transfer Learning and Fine tuning by Prince Kumar

# %%
! mkdir -p ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
#!/bin/bash
# !kaggle datasets download sunilthite/cat-or-dog-image-classification
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/sunilthite/cat-or-dog-image-classification
# License(s): other
# Downloading cat-or-dog-image-classification.zip to /content
#  95% 572M/599M [00:08<00:00, 59.1MB/s]
# 100% 599M/599M [00:08<00:00, 74.7MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/cat-or-dog-image-classification.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense,Flatten

# %%
conv_base = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(150,150, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 150, 150, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 150, 150, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 75, 75, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 75, 75, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 37, 37, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 37, 37, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 37, 37, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 18, 18, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 18, 18, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 18, 18, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 9, 9, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 9, 9, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = Sequential()

model.add(conv_base)  # pretrained model (VGG16)
model.add(Flatten())

model.add(Dense(256, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,812,353 (64.13 MB)
#  Trainable params: 16,812,353 (64.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
conv_base.trainable=False

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory="/content/Train",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(150,150)
)


val_ds = keras.utils.image_dataset_from_directory(
    directory="/content/Test",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(150,150)
)
# Out:
# Found 23650 files belonging to 2 classes.
# Found 3863 files belonging to 2 classes.

# %%
#normalize
def process(image,label):
  image = tensorflow.cast(image/255. ,tensorflow.float32)
  return image,label

train_ds = train_ds.map(process)
val_ds = val_ds.map(process)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=10, validation_data=val_ds,)
# Out:
# Epoch 1/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 101s 124ms/step - accuracy: 0.8504 - loss: 0.3815 - val_accuracy: 0.9195 - val_loss: 0.1883
# Epoch 2/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9156 - loss: 0.2062 - val_accuracy: 0.9205 - val_loss: 0.1908
# Epoch 3/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9278 - loss: 0.1701 - val_accuracy: 0.9340 - val_loss: 0.1630
# Epoch 4/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9432 - loss: 0.1436 - val_accuracy: 0.9475 - val_loss: 0.1387
# Epoch 5/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9546 - loss: 0.1137 - val_accuracy: 0.9480 - val_loss: 0.1384
# Epoch 6/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9653 - loss: 0.0933 - val_accuracy: 0.9459 - val_loss: 0.1390
# Epoch 7/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9703 - loss: 0.0756 - val_accuracy: 0.9498 - val_loss: 0.1439
# Epoch 8/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 86s 116ms/step - accuracy: 0.9827 - loss: 0.0516 - val_accuracy: 0.9467 - val_loss: 0.1464
# Epoch 9/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9858 - loss: 0.0393 - val_accuracy: 0.9529 - val_loss: 0.1529
# Epoch 10/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 85s 115ms/step - accuracy: 0.9880 - loss: 0.0326 - val_accuracy: 0.9311 - val_loss: 0.2188

# %%
conv_base.trainable = True

for layer in conv_base.layers[:15]:
    layer.trainable = False


model.compile(
    optimizer=keras.optimizers.Adam(1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history_finetune = model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 109s 142ms/step - accuracy: 0.9817 - loss: 0.0481 - val_accuracy: 0.9643 - val_loss: 0.1163
# Epoch 2/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.9739 - val_loss: 0.0922
# Epoch 3/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9749 - val_loss: 0.0985
# Epoch 4/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 137ms/step - accuracy: 0.9996 - loss: 0.0034 - val_accuracy: 0.9728 - val_loss: 0.1013
# Epoch 5/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9996 - loss: 0.0024 - val_accuracy: 0.9723 - val_loss: 0.1103
# Epoch 6/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9978 - loss: 0.0074 - val_accuracy: 0.9746 - val_loss: 0.0987
# Epoch 7/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 111s 150ms/step - accuracy: 0.9972 - loss: 0.0085 - val_accuracy: 0.9772 - val_loss: 0.0914
# Epoch 8/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.9788 - val_loss: 0.0827
# Epoch 9/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9995 - loss: 0.0030 - val_accuracy: 0.9816 - val_loss: 0.0826
# Epoch 10/10
# 740/740 ━━━━━━━━━━━━━━━━━━━━ 102s 138ms/step - accuracy: 0.9999 - loss: 5.1779e-04 - val_accuracy: 0.9811 - val_loss: 0.0874

# %%
# model.save("dog_cat_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img_path = "/content/download (4).jpeg"

img = image.load_img(img_path, target_size=(150, 150))
x = image.img_to_array(img) / 255.0
x = np.expand_dims(x, axis=0)

prediction = model.predict(x)[0][0]

if prediction > 0.5:
    print("Dog 🐶")
else:
    print("Cat 🐱")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Cat 🐱
